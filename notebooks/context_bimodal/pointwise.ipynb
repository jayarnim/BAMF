# %%
MODEL = "context_bimodal"
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../.."
PATH_CONFIG_FILE = f"./config/{MODEL}/{STRATEGY}.yaml"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\RESEARCH\2024-2 지능정보시스템학회 추계학술대회\BAMF

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
import yaml
from recsys import config, experiment, bamf

# %%
kwargs = dict(
    file=PATH_CONFIG_FILE,
    mode="r",
    encoding="utf-8",
)
with open(**kwargs) as f:
    cfg = yaml.safe_load(f)

# %%
experiment_cfg = config.parser.experiment.experiment(cfg)
schema_cfg = config.parser.experiment.schema(cfg)
pipeline_cfg = config.parser.experiment.pipeline(cfg)
trainer_cfg = config.parser.experiment.trainer(cfg)
evaluator_cfg = config.parser.experiment.evaluator(cfg)
model_cfg = config.parser.model.auto(cfg)

# %%
experiment.utils.seed.reset(experiment_cfg)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/{experiment_cfg.data}.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    cfg=schema_cfg,
    percentaile=0.9,
)

experiment.utils.data_handler.description(**kwargs)
# Out:
# number of user: 610
# number of item: 9724
# total interaction: 100836
# interaction density: 1.7000 %
# max interaction of user: 2698
# max interaction of item: 329
# top 10.0 % interaction of user: 400.3
# top 10.0 % interaction of item: 27.0
# mean interaction of user: 165
# mean interaction of item: 10

# %%
kwargs = dict(
    df=df,
    cfg=pipeline_cfg,
)

dataloaders, interactions, histories = experiment.pipeline.builder.pipeline_builder(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    histories=histories,
    cfg=model_cfg,
)

model = bamf.context_bimodal.Module(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=trainer_cfg,
)

trainer = experiment.trainer.builder.trainer_builder(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
    dev_loader=dataloaders["dev"],
)

record = trainer.fit(**kwargs)
# Out:
# DEVELOPMENT
# 	BEST SCORE: 0.6353
# 	BEST EPOCH: 13

# %%
kwargs = dict(
    records=[record["trn"]["nll"], record["val"]["nll"]],
    labels=["TRN", "VAL"],
    criterion="BCE",
    title="BAMF NLL (TRN VS VAL)"
)

experiment.utils.visualizer.compare_curve(**kwargs)

# %%
kwargs = dict(
    records=[record["trn"]["kl"], record["val"]["kl"]],
    labels=["TRN", "VAL"],
    criterion="KL DIVERGENCE",
    title="BAMF KL (TRN VS VAL)"
)

experiment.utils.visualizer.compare_curve(**kwargs)

# %%
kwargs = dict(
    record=record["dev"],
    label="DEV",
    criterion="NDCG@10",
    title="GMF METRIC (DEV)",
)

experiment.utils.visualizer.criterion_curve(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cfg=evaluator_cfg,
)

evaluator = experiment.evaluator.builder.evaluator_builder(**kwargs)

# %%
result, metrics_sheet = evaluator(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 3916/3916 [00:21<00:00, 183.65it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.927869   0.466557  0.349828  0.277682  0.562164
# 1  10   0.957377   0.355246  0.469006  0.334460  0.560727
# 2  15   0.975410   0.293880  0.543234  0.360130  0.568811
# 3  20   0.986885   0.251885  0.587990  0.373263  0.575027
# 4  25   0.996721   0.224131  0.629367  0.383076  0.583575
# 5  50   1.000000   0.146754  0.733471  0.404930  0.608176

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{experiment_cfg.model}/{experiment_cfg.strategy}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

experiment.utils.checkpointer.save(**kwargs)
