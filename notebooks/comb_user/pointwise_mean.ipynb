# %%
MODEL = "comb_user"
COMB = "mean"
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../.."

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\RESEARCH\2024-2 지능정보시스템학회 추계학술대회\BAMF

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
from recsys import config, pipeline, trainer, evaluator, utils
import bamf

# %%
PATH = f"./config/{MODEL}/{STRATEGY}_{COMB}.yaml"
cfg = config.builder.config_builder(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/{cfg.dataset}.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    cfg=cfg.pipeline,
)

dataloaders, interactions, histories = pipeline.builder.pipeline_builder(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    histories=histories["user"],
    num_users=cfg.model.num_users,
    num_items=cfg.model.num_items,
    **cfg.model.params,
)

model = bamf.comb_user.Module(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

trainer = trainer.builder.trainer_builder(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = trainer.fit(**kwargs)
# Out:
# VALIDATION
# 	BEST SCORE: 0.5603
# 	BEST EPOCH: 34

# %%
kwargs = dict(
    record=records["trn"]["nll"],
    label="TRN",
    criterion="BCE",
    title="COMB_USER NLL (TRN)",
)

utils.visualizer.main(**kwargs)

# %%
kwargs = dict(
    record=records["trn"]["kl"],
    label="TRN",
    criterion="KL DIVERGENCE",
    title="COMB_USER KL (TRN)",
)

utils.visualizer.main(**kwargs)

# %%
kwargs = dict(
    record=records["val"],
    label="VAL",
    criterion="NDCG@10",
    title="COMB_USER METRIC (VAL)",
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cfg=cfg.evaluator,
)

evaluator = evaluator.builder.evaluator_builder(**kwargs)

# %%
result, metrics_sheet = evaluator(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 3941/3941 [00:18<00:00, 209.24it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.875410   0.443279  0.314007  0.246553  0.518461
# 1  10   0.952459   0.348197  0.441848  0.302403  0.526648
# 2  15   0.973770   0.295082  0.524417  0.329950  0.541490
# 3  20   0.981967   0.259426  0.579601  0.345625  0.554111
# 4  25   0.981967   0.231410  0.612908  0.355383  0.561099
# 5  50   0.991803   0.157180  0.722286  0.380123  0.588396

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{cfg.model_cls}/{cfg.strategy}_{cfg.comb}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
